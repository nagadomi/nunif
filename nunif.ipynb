# %%
# !apt-get install git-core libmagickwand-dev libsnappy-dev libraqm-dev
# !git clone https://github.com/nagadomi/nunif.git
# %cd nunif
# !pip3 install torch torchvision torchaudio torchtext
# !pip3 install -r requirements.txt
# !python -m waifu2x.download_models
# !python -m waifu2x.web.webgen
# Out:
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Note, selecting 'git' instead of 'git-core'
# git is already the newest version (1:2.25.1-1ubuntu3.11).
# The following additional packages will be installed:
#   fonts-droid-fallback fonts-noto-mono fonts-urw-base35 ghostscript
#   gir1.2-freedesktop gir1.2-gdkpixbuf-2.0 gir1.2-harfbuzz-0.0 gir1.2-rsvg-2.0
#   gsfonts imagemagick-6-common libblkid-dev libblkid1
#   libcairo-script-interpreter2 libcairo2-dev libdjvulibre-dev
#   libdjvulibre-text libdjvulibre21 libffi-dev libfribidi-dev
#   libgdk-pixbuf2.0-bin libgdk-pixbuf2.0-dev libglib2.0-dev libglib2.0-dev-bin
#   libgraphite2-dev libgs9 libgs9-common libharfbuzz-dev libharfbuzz-gobject0
#   libharfbuzz-icu0 libidn11 libijs-0.35 libjbig2dec0 liblcms2-dev liblqr-1-0
#   liblqr-1-0-dev liblzo2-2 libmagickcore-6-arch-config libmagickcore-6-headers
#   libmagickcore-6.q16-6 libmagickcore-6.q16-6-extra libmagickcore-6.q16-dev
# ...

# %%
# Run with colab. GPU must be selected at runtime!
from google.colab.output import eval_js
url = eval_js("google.colab.kernel.proxyPort(8812)")
print('Open the link to use manga-image-translator! -> ', url)
# !python -m waifu2x.web --no-size-limit --cache-ttl 120 --tile-size 400
# Out:
# Open the link to use manga-image-translator! ->  https://fqi0e0sdd2k-496ff2e9c6d22116-8812-colab.googleusercontent.com/
# /usr/local/lib/python3.10/dist-packages/torch/_utils.py:776: UserWarning: TypedStorage is deprecated. It will be removed in the future and UntypedStorage will be the only storage class. This should only matter to you if you are using storages directly.  To access UntypedStorage directly, use tensor.untyped_storage() instead of tensor.storage()
#   return self.fget.__get__(instance, owner)()
# Bottle v0.12.25 server starting up (using WaitressServer(preload_app=True, threads=32, outbuf_overflow=20971520, inbuf_overflow=20971520, max_request_body_size=1073741824, connection_limit=256, channel_timeout=120))...
# Listening on http://127.0.0.1:8812/
# Hit Ctrl-C to quit.
#
# 2023-06-28 16:42:35,534:nunif: [    INFO] diskcache: cache=0.03MB, RAM=1920.41
